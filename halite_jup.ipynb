# %%
# !halite.exe --replay-directory replays/ -vvv --width 32 --height 32 "python MyBot.py" "python MyBot.py"

# %%
# !halite --help
# Out:
# USAGE:
#
#    halite  [-v] ...  [-o <name strings>] ...  [-m <[basic | blur_tile |
#            fractal]>] [--from-snapshot <snapshot generated by visualizer>]
#            [-c <path to file>] [-i <path to directory>] [--turn-limit
#            <positive integer>] [-s <positive integer>] [--height <positive
#            integer>] [--width <positive integer>] [-n <positive integer>]
#            [--strict] [--results-as-json] [--no-compression]
#            [--print-constants] [--no-logs] [--no-replay] [--no-timeout]
#            [--] [--version] [-h] <path strings> ...
#
#
# Where:
#
#    -v,  --verbosity  (accepted multiple times)
#      Increase the logging verbosity level.
#
#    -o <name strings>,  --override-names <name strings>  (accepted multiple
#       times)
#      Overrides player-sent names.
#
#    -m <[basic | blur_tile | fractal]>,  --map-type <[basic | blur_tile |
#       fractal]>
#      The map type.
#
#    --from-snapshot <snapshot generated by visualizer>
# ...

# %%
import hlt
help(hlt.Direction)
# Out:
# Help on class Direction in module hlt.positionals:
#
# class Direction(builtins.object)
#  |  Holds positional tuples in relation to cardinal directions
#  |
#  |  Static methods defined here:
#  |
#  |  convert(direction)
#  |      Converts from this direction tuple notation to the engine's string notation
#  |      :param direction: the direction in this notation
#  |      :return: The character equivalent for the game engine
#  |
#  |  get_all_cardinals()
#  |      Returns all contained items in each cardinal
#  |      :return: An array of cardinals
#  |
#  |  invert(direction)
#  |      Returns the opposite cardinal direction given a direction
#  |      :param direction: The input direction
#  |      :return: The opposite direction
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
# ...

# %%
dic = {'dock1' : ["off",1], 'dock2' : ["on",2], 'dock3' : ["off",3], 'dock4' : ["on",4]}

T = True
for k in dic:
    if dic[k][0] == "esc":
        T = False
        break
    else:
        continue
if T == True:
    print('off non nella lista')
# Out:
# off non nella lista
